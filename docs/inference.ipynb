# %% [markdown]
# <h1>Inference Engine</h1>

# %%
import sys
sys.path.append("../")
sys.path.append("../../")
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from inference import *

# %%
# Generate the initial parameters.
prior = 0
data = 0

# %%
input_space = [[0, 1], [0, 1]]
x = linspace(0, 1, 25)
output_space = [0, 2]

model = lambda k: k[0] * x + k[1]#b=1
model_rv = ModelRandomVariable(input_space, output_space, model)

# %%
a = numpy.array([0.3, 0.5, 0.6])
plots = [plot(x, model([_a, 1]), 'o') for _a in a]
xlabel('x')
ylabel('y')

# %%
a_exact = 0.4 # True underlying parameter attempting to estimate
sigma = 0.05
y_data = model([a_exact, 1]) + sigma * numpy.random.randn(*(x.shape))
plot(x, model([a_exact, 1]))
plot(x, y_data, 'o')

# %%
data = NormalDistribution(y_data, sigma * sigma)
prior = UniformDistribution(input_space)

# %%
posterior = Posterior(prior, model_rv, data)

# %%
a = linspace(0.3, 0.7, 101)
#likelihoods = [posterior.L([_a, 1]) for _a in a]
a = linspace(-1, 2, 100)
b = linspace(-0.5, 2.5, 100)
likelihoods = [[-np.log(posterior.L([_a, _b])) for _b in b] for _a in a]
imshow(likelihoods, extent=[-1,2,-0.5,2.5])
#plot(a, likelihoods)

# %%
ml = posterior.maximum_likelihood([0.3, 1.2])
ml
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-120db17b3130> in <module>()
# ----> 1 ml = posterior.maximum_likelihood([0.3, 0.8])
#       2 ml
#
# /home/rtaylor/projects/enzymatica/inference/posterior.py in maximum_likelihood(self, x0)
#      39     f = lambda x: -np.log(self.L(x)) # Once the function f has been initialized.
#      40     # This is expecting x to be a vector.
# ---> 41     result = optimize.minimize(f,x0, method='Anneal')
#      42     return result # Estimate and covariance structure.
#      43
#
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     351                                   **options)
#     352     elif meth == 'anneal':
# --> 353         return _minimize_anneal(fun, x0, args, **options)
#     354     elif meth == 'l-bfgs-b':
#     355         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/anneal.pyc in _minimize_anneal(func, x0, args, schedule, T0, Tf, maxfev, maxaccept, maxiter, boltzmann, learn_rate, ftol, quench, m, n, lower, upper, dwell, disp, **unknown_options)
#     386
#     387     last_state.x = asarray(x0).copy()
# --> 388     fval = func(x0,*args)
#     389     schedule.feval += 1
#     390     last_state.cost = fval
#
# /home/rtaylor/projects/enzymatica/inference/posterior.py in <lambda>(x)
#      37
#      38     x0 = np.array(x0).T
# ---> 39     f = lambda x: -np.log(self.L(x)) # Once the function f has been initialized.
#      40     # This is expecting x to be a vector.
#      41     result = optimize.minimize(f,x0, method='Anneal')
#
# /home/rtaylor/projects/enzymatica/inference/posterior.py in L(self, x)
#      21     """
#      22     if self.model.is_deterministic:
# ---> 23       d = self.model.model(x)
#      24       return self.prior.L(x) * self.data.L(d)
#      25     else:
#
# <ipython-input-8-01c8840bcac8> in <lambda>(k)
#       3 output_space = [0, 2]
#       4
# ----> 5 model = lambda k: k[0] * x + k[1]#b=1
#       6 model_rv = ModelRandomVariable(input_space, output_space, model)
#
# TypeError: 'NoneType' object has no attribute '__getitem__'
# ../inference/posterior.py:39: RuntimeWarning: divide by zero encountered in log
#   f = lambda x: -np.log(self.L(x)) # Once the function f has been initialized.
